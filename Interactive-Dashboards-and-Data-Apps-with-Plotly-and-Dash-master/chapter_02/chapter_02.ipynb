# %% [markdown]
# # Chapter 2 - Exploring the Structure of a Dash App
#
# * Using Jupyter Notebooks to run Dash apps
# * Creating a standalone pure Python function
# * Understanding the id parameter of Dash components
# * Using Dash Inputs and Outputs
# * Incorporating the function into the app - creating your first reactive program
# * Running your first interactive app

# %%
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output, Input

app = JupyterDash(__name__)

app.layout = html.Div([
    dcc.Dropdown(id='color_dropdown',
                 options=[{'label': color, 'value': color}
                          for color in ['blue', 'green', 'yellow']]),
    html.Br(),
    html.Div(id='color_output')
])

@app.callback(Output('color_output', 'children'),
              Input('color_dropdown', 'value'))
def display_selected_color(color):
    if color is None:
        color = 'nothing'
    return 'You selected ' + color

if __name__ == '__main__':
    app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os
os.listdir('../data')
# Out:
# ['lat_long.csv',
#  'poverty.csv',
#  'PovStatsCountry-Series.csv',
#  'PovStatsCountry.csv',
#  'PovStatsData.csv',
#  'PovStatsFootNote.csv',
#  'PovStatsSeries.csv']

# %%
import pandas as pd
poverty_data = pd.read_csv('../data/PovStatsData.csv')
poverty_data.head(3)
# Out:
#           Country Name Country Code  \
# 0  East Asia & Pacific          EAS
# 1  East Asia & Pacific          EAS
# 2  East Asia & Pacific          EAS
#
#                                       Indicator Name  Indicator Code  1974  \
# 0  Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 1  Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 2  Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
#
#    1975  1976  1977  1978  1979  ...  2011  2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2017  2018  2019  Unnamed: 50
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
#
# [3 rows x 51 columns]

# %%
# !pip install jupyter-dash dash dash-bootstrap-components pandas plotly 
# !pip install dash_html_components dash_core_components
# Out:
# Requirement already satisfied: jupyter-dash in c:\users\reach\miniforge3\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\reach\miniforge3\lib\site-packages (3.0.4)
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas in c:\users\reach\miniforge3\lib\site-packages (2.3.0)
# Requirement already satisfied: plotly in c:\users\reach\miniforge3\lib\site-packages (6.1.2)
# Requirement already satisfied: requests in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: retrying in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (9.3.0)
# Requirement already satisfied: ipykernel in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (6.29.5)
# Requirement already satisfied: ansi2html in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in c:\users\reach\miniforge3\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\reach\miniforge3\lib\site-packages (from dash) (3.0.6)
# Requirement already satisfied: importlib-metadata in c:\users\reach\miniforge3\lib\site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\reach\miniforge3\lib\site-packages (from dash) (4.14.0)
# Requirement already satisfied: setuptools in c:\users\reach\miniforge3\lib\site-packages (from dash) (80.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\reach\miniforge3\lib\site-packages (from flask->jupyter-dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\reach\miniforge3\lib\site-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\reach\miniforge3\lib\site-packages (from flask->jupyter-dash) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\reach\miniforge3\lib\site-packages (from flask->jupyter-dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\reach\miniforge3\lib\site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\reach\miniforge3\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reach\miniforge3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reach\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reach\miniforge3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\reach\miniforge3\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\reach\miniforge3\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: colorama in c:\users\reach\miniforge3\lib\site-packages (from click>=8.1.3->flask->jupyter-dash) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\reach\miniforge3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\reach\miniforge3\lib\site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: psutil in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\reach\miniforge3\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\reach\miniforge3\lib\site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\reach\miniforge3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\reach\miniforge3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\reach\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\reach\miniforge3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (310)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\reach\miniforge3\lib\site-packages (from requests->jupyter-dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reach\miniforge3\lib\site-packages (from requests->jupyter-dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\reach\miniforge3\lib\site-packages (from requests->jupyter-dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reach\miniforge3\lib\site-packages (from requests->jupyter-dash) (2025.4.26)
# Requirement already satisfied: executing>=1.2.0 in c:\users\reach\miniforge3\lib\site-packages (from stack_data->ipython->jupyter-dash) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\reach\miniforge3\lib\site-packages (from stack_data->ipython->jupyter-dash) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\reach\miniforge3\lib\site-packages (from stack_data->ipython->jupyter-dash) (0.2.3)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-2.0.4
# Collecting dash_html_components
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash_core_components
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: dash_html_components, dash_core_components
#
#    -------------------- ------------------- 1/2 [dash_core_components]
#    ---------------------------------------- 2/2 [dash_core_components]
#
# Successfully installed dash_core_components-2.0.0 dash_html_components-2.0.0

# %%
from jupyter_dash import JupyterDash
import dash_html_components as html
import dash_core_components as dcc
import dash_bootstrap_components as dbc
from dash.dependencies import Output, Input

app = JupyterDash(__name__)

app.layout = html.Div([
        dcc.Dropdown(id='country',
                     options=[{'label': country, 'value': country}
                              for country in poverty_data['Country Name'].unique()]),
        html.Br(),
        html.Div(id='report')
])

@app.callback(Output('report', 'children'),
              Input('country', 'value'))
def display_country_report(country):
    if country is None:
        return ''
    filtered_df = poverty_data[(poverty_data['Country Name']==country) &
                             (poverty_data['Indicator Name']=='Population, total')]
    population = filtered_df.loc[:, '2018'].values[0]

    return [html.H3(country),
            f'The population of {country} in 2018 was {population:,.0f}.']

if __name__ == '__main__':
    app.run(mode='external', height=200, width='30%', port=8051)
# Out:
# C:\Users\reach\AppData\Local\Temp\ipykernel_7996\2532314020.py:2: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# C:\Users\reach\AppData\Local\Temp\ipykernel_7996\2532314020.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# c:\Users\reach\miniforge3\Lib\site-packages\dash\dash.py:587: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       5 from dash.dependencies import Output, Input
#       7 app = JupyterDash(__name__)
#       9 app.layout = html.Div([
#      10         dcc.Dropdown(id='country',
#      11                      options=[{'label': country, 'value': country}
# ---> 12                               for country in poverty_data['Country Name'].unique()]),
#      13         html.Br(),
#      14         html.Div(id='report')
#      15 ])
#      17 @app.callback(Output('report', 'children'),
#      18               Input('country', 'value'))
#      19 def display_country_report(country):
#      20     if country is None:
#
# NameError: name 'poverty_data' is not defined
